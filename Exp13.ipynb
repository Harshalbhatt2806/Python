# %%
file1 = open(r"E:\MU\PWP\reamianing\ict.txt")
print(data)
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
f1 = open(r"E:\MU\PWP\reamianing\ict.txt")
# This will print every line one by one in the file
for each in f1:
    print (each)
# Out:
# ICT ICT ICT
#
# ICT ICT ICT ICT ICT

# %%
# Python code to illustrate read() mode
f1 = open(r"E:\MU\PWP\reamianing\ict.txt")
print (f1.read())
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
with open(r"E:\MU\PWP\reamianing\ict.txt",'r') as f1:  
    data = f1.read() 
print(data)
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
f1 = open(r"E:\MU\PWP\reamianing\ict.txt")
print (f1.read(5))
# Out:
# ICT I

# %%
with open(r"E:\MU\PWP\reamianing\ict.txt",'r') as file:
    data = file.readlines()
    for line in data:
        word = line.split()
        print (word)
# Out:
# ['ICT', 'ICT', 'ICT']
# ['ICT', 'ICT', 'ICT', 'ICT', 'ICT']

# %%
file = open("ict1.txt",'w')
file.write("ICT ICT ICT \n")
file.write("ICT ICT ICT ICT ICT")
file.close()

# %%
with open("file.txt", "w") as f: 
    f.write("Hello World!!!") 
    f.close()

# %%
file = open("ict1.txt",'a')
file.write("\n Department Department")
file.close()

# %%
with open(r'E:\MU\PWP\reamianing\a.tif', 'rb') as file:
    binary_data = file.read()
print(data)
# Out:
# ['ICT ICT ICT \n', 'ICT ICT ICT ICT ICT']

# %%
with open('c.tif', 'wb') as f:
    f.write(binary_data)
    f.close()

# %%
import csv
# Reading from a CSV file
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 import csv
#       2 # Reading from a CSV file
# ----> 3 with open('data.csv', 'r') as file:
#       4     reader = csv.reader(file)
#       5     for row in reader:
#
# File c:\Users\Harshal Bhatt\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'

# %%
import csv
with open('output.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Subject', 'Mark'])
    writer.writerow(['Aansh', 'PWP', 9])
    writer.writerow(['Ashutosh', 'PWP', 10])
    file.close()
